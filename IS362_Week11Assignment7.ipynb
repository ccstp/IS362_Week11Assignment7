# %% [markdown]
# # IS 362 - Week 11 Assignment
#
# ### Your task is to choose one of the New York Times APIs, construct an interface in Python to read in the JSON data, and transform it into a pandas DataFrame.

# %%
# Import libraries

import json as json
import requests
import pandas as pan
from pandas import json_normalize

# %%
# NYTimes Most Popular Articles API

api_key = "6sjKGI0eFUfj7hm6DTL4n1kLmJGxnycW"

# Most viewed NYTimes.com articles in the last 30 days 

url = "https://api.nytimes.com/svc/mostpopular/v2/viewed/30.json"

# %%
# Make API request

request = requests.get(url, params={'api-key': api_key})

# Parse the JSON response

data = request.json()

# %%
# Display the JSON data

data
# Out:
# {'status': 'OK',
#  'copyright': 'Copyright (c) 2023 The New York Times Company.  All Rights Reserved.',
#  'num_results': 20,
#  'results': [{'uri': 'nyt://article/9b034326-2da1-55b3-94cc-68bd693d05ae',
#    'url': 'https://www.nytimes.com/2023/04/26/business/media/tucker-carlson-dominion-fox-news.html',
#    'id': 100000008874473,
#    'asset_id': 100000008874473,
#    'source': 'New York Times',
#    'published_date': '2023-04-26',
#    'updated': '2023-04-28 15:27:38',
#    'section': 'Business',
#    'subsection': 'Media',
#    'nytdsection': 'business',
#    'adx_keywords': 'Boards of Directors;Television;News and News Media;Text Messaging;Libel and Slander;Suits and Litigation (Civil);Workplace Hazards and Violations;internal-sub-only;Carlson, Tucker;Murdoch, Lachlan;Murdoch, Rupert;Grossberg, Abby;Fox News Channel;Dominion Voting Systems Corp;Smartmatic SGO Group',
#    'column': None,
#    'byline': 'By Jim Rutenberg, Jeremy W. Peters and Michael S. Schmidt',
# ...

# %%
# Create the pandas dataframe from the requested NYTimes JSON data

most_viewed = pan.json_normalize(data['results'])

# Display the information in the dataframe, listing only a select set of columns for readability

most_viewed[['title','byline','published_date']]
# Out:
#                                                 title  \
# 0   On Eve of Trial, Discovery of Carlson Texts Se...
# 1   Don Lemon Ousted From CNN in Move That Left Hi...
# 2   Gunman Kills 5 Co-Workers at Louisville Bank o...
# 3   How to Claim Your Share of Facebook’s $725 Mil...
# 4   Ukraine War Plans Leak Prompts Pentagon Invest...
# 5   84-Year-Old Is Charged in Shooting of Black Te...
# 6   Jerry Springer, Host of a Raucous TV Talk Show...
# 7   Analysis: A Surprise Accusation Bolsters a Ris...
# 8   Leaked Documents Reveal Depth of U.S. Spy Effo...
# 9   At Least 32 Killed as Tornadoes Tear Through t...
# 10  N.F.L. Draft Picks 2023: All the Results From ...
# 11  Carolyn Bryant Donham Dies at 88; Her Words Do...
# 12  Harry Belafonte, 96, Dies; Barrier-Breaking Si...
# 13          My Transplanted Heart and I Will Die Soon
# 14  What Is the Ideal Retirement Age for Your Health?
# 15  Bragg Sues Jim Jordan in Move to Block Interfe...
# ...
